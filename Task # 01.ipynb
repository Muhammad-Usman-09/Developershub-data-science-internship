# %% [markdown]
#                                 DevelopersHub Corporation
#                             Data Science &amp; Analytics Internship Tasks
#                                     Due Date: 14th August, 2025

# %% [markdown]
# ---

# %% [markdown]
#                                   Muhammad Usman Fakhar
#                                 Data Science & Analytics
#                                         DHC-1379

# %% [markdown]
# ---

# %%
2+2
# Out:
# 4

# %%
print(("hello world!"))
# Out:
# hello world!

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
#                                              Task 1: Exploring and Visualizing a Simple Dataset
#
# **Objective:**
# Understand how to read, summarize, and visualize a dataset.

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris_df = pd.read_csv(r"C:\Users\Dell\OneDrive - Higher Education Commission\Desktop\internship\Task # 01\Iris.csv")
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
print("Shape of dataset:", iris_df.shape)
# Out:
# Shape of dataset: (150, 6)

# %%
print("Columns:", iris_df.columns)
# Out:
# Columns: Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris_df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
#                                             Task1_Iris_Visualization

# %%
#Scatter plot 
plt.figure(figsize=(10, 6))
sns.scatterplot(data=iris_df, x='SepalLengthCm', y='SepalWidthCm', hue='Species', style='Species', s=100)
plt.title('Sepal Length vs Sepal Width by Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend(title='Species')
plt.show()

# %%
#Histogram
plt.figure(figsize=(10, 6))
sns.histplot(data=iris_df, x='SepalLengthCm', hue='Species', multiple='stack', kde=True)
plt.title('Distribution of Sepal Length by Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
#Box plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=iris_df, x='Species', y='SepalLengthCm')
plt.title('Box Plot of Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# %% [markdown]
# **Conclusion**
#
# 1. The Iris dataset is a classic dataset in the field of data science and machine learning.
#
# 2. It consists of 150 samples of iris flowers, each with four features: sepal length, sepal width, petal length, and petal width.
#
# 3. The dataset is divided into three species of iris flowers: setosa, versicolor, and virginica.
#
# 4. The dataset is often used for classification tasks, such as identifying the species of an iris flower based on its features.

# %% [markdown]
# ---
# ---
# ---
